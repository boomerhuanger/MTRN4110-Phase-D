# %%
# Import libraries
import cv2 
import numpy as np

def nothing(x): pass

# Load image
image = cv2.imread('../Maze.png')

# Create a window
cv2.namedWindow('image', cv2.WINDOW_NORMAL) 
cv2.resizeWindow('image', 900, 700)

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing) 
cv2.createTrackbar('SMin', 'image', 0, 255, nothing) 
cv2.createTrackbar('VMin', 'image', 0, 255, nothing) 
cv2.createTrackbar('HMax', 'image', 0, 179, nothing) 
cv2.createTrackbar('SMax', 'image', 0, 255, nothing) 
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179) 
cv2.setTrackbarPos('SMax', 'image', 255) 
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0 
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):

    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)
    
    # Convert grayscale image to color image for displaying simultaneous
    mask_3_channel = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
    
    # Stack images
    numpy_horizontal = np.hstack((image, result, mask_3_channel))
    
    # Display HSV values of some colours
    cv2.putText(numpy_horizontal, 'Black: (0, 0, 0)', (130, 15), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'White: (0, 0, 255)', (130, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Red: (0, 255, 255)', (130, 45), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Green: (60, 255, 255)', (130, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Blue: (120, 255, 255)', (130, 75), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display stacked image, press q to quit
    cv2.imshow('image', numpy_horizontal)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 31 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 38 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 40 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 47 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 49 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 51 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 52 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 53 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 54 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 58 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 62 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 63 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 65 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 68 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 70 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 71 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 73 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 74 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 75 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 77 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 53, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 55, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 50, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 49, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 45, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 44, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 41, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 3), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 17), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 71), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 113), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 134), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 149), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 158), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 160), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 158), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 159), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 160), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 161), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 163), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 164), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 167), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 170), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 174), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 179), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 184), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 188), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 190), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 195), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 198), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 199), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 201), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 206), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 212), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 216), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 217), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 218), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 219), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 220), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 221), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 222), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 223), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 224), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 225), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 226), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 227), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 228), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 229), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 160 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 139 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 132 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 126 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 111 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 107 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 104 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 101 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 100 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 98 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 99 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 40, vMin = 230), (hMax = 100 , sMax = 255, vMax = 255)
# (hMin = -1 , sMin = -1, vMin = -1), (hMax = -1 , sMax = -1, vMax = -1)
